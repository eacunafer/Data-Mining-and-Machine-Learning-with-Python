# %% [markdown]
# ## Data Mining and Machine Learning
# ### Edgar Acuna
# ###  mean/median/mode Imputation: Census Dataset

# %%
import pandas as pd
datos = pd.read_csv('c://PW-PR/census.csv', sep=',',na_values=[' ?'])
print(datos.shape)
# Out:
# (32561, 16)

# %%
datos.head()
# Out:
#    Unnamed: 0  age         employment  final-weight   education  \
# 0           1   39          State-gov         77516   Bachelors
# 1           2   50   Self-emp-not-inc         83311   Bachelors
# 2           3   38            Private        215646     HS-grad
# 3           4   53            Private        234721        11th
# 4           5   28            Private        338409   Bachelors
#
#    education.num       marital.status                 job    relationship  \
# 0             13        Never-married        Adm-clerical   Not-in-family
# 1             13   Married-civ-spouse     Exec-managerial         Husband
# 2              9             Divorced   Handlers-cleaners   Not-in-family
# 3              7   Married-civ-spouse   Handlers-cleaners         Husband
# 4             13   Married-civ-spouse      Prof-specialty            Wife
#
#      race   gender  capital-gain  capital-loss  hours.per.week  \
# 0   White     Male          2174             0              40
# ...

# %%
#Excluyendo la columna de clase: class
x=datos.iloc[:,:-1]

# %%
x.head(20)
# Out:
#     Unnamed: 0  age         employment  final-weight      education  \
# 0            1   39          State-gov         77516      Bachelors
# 1            2   50   Self-emp-not-inc         83311      Bachelors
# 2            3   38            Private        215646        HS-grad
# 3            4   53            Private        234721           11th
# 4            5   28            Private        338409      Bachelors
# 5            6   37            Private        284582        Masters
# 6            7   49            Private        160187            9th
# 7            8   52   Self-emp-not-inc        209642        HS-grad
# 8            9   31            Private         45781        Masters
# 9           10   42            Private        159449      Bachelors
# 10          11   37            Private        280464   Some-college
# 11          12   30          State-gov        141297      Bachelors
# 12          13   23            Private        122272      Bachelors
# ...

# %% [markdown]
# ### Since the missing values are in categorial features we use mode imputation

# %%
#Another way to cumpute the mode
y=datos['education.num']
y.value_counts().index[0]
# Out:
# 9

# %%
dfclean = x.apply(lambda x:x.fillna(x.value_counts().index[0]))

# %% [markdown]
# Checking that the dataset is complete

# %%
dfclean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# Unnamed: 0        32561 non-null int64
# age               32561 non-null int64
# employment        32561 non-null object
# final-weight      32561 non-null int64
# education         32561 non-null object
# education.num     32561 non-null int64
# marital.status    32561 non-null object
# job               32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# gender            32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours.per.week    32561 non-null int64
# native.country    32561 non-null object
# dtypes: int64(7), object(8)
# memory usage: 3.7+ MB

# %%
dfclean.head(20)
# Out:
#     Unnamed: 0  age         employment  final-weight      education  \
# 0            1   39          State-gov         77516      Bachelors
# 1            2   50   Self-emp-not-inc         83311      Bachelors
# 2            3   38            Private        215646        HS-grad
# 3            4   53            Private        234721           11th
# 4            5   28            Private        338409      Bachelors
# 5            6   37            Private        284582        Masters
# 6            7   49            Private        160187            9th
# 7            8   52   Self-emp-not-inc        209642        HS-grad
# 8            9   31            Private         45781        Masters
# 9           10   42            Private        159449      Bachelors
# 10          11   37            Private        280464   Some-college
# 11          12   30          State-gov        141297      Bachelors
# 12          13   23            Private        122272      Bachelors
# ...

# %%
#Imputacion por la moda usando scikit-learn si la variable es cuantitativa y por la moda si la variable es  cualitativa 
import numpy as np
from sklearn.preprocessing import Imputer
from sklearn.base import TransformerMixin

class DataFrameImputer(TransformerMixin):

    def fit(self, X, y=None):

        self.fill = pd.Series([X[c].value_counts().index[0]
            if X[c].dtype == np.dtype('O') else X[c].mean() for c in X],
            index=X.columns)

        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)
X=x
xt = DataFrameImputer().fit_transform(X)

# %%
xt.head(20)
# Out:
#     Unnamed: 0  age         employment  final-weight      education  \
# 0            1   39          State-gov         77516      Bachelors
# 1            2   50   Self-emp-not-inc         83311      Bachelors
# 2            3   38            Private        215646        HS-grad
# 3            4   53            Private        234721           11th
# 4            5   28            Private        338409      Bachelors
# 5            6   37            Private        284582        Masters
# 6            7   49            Private        160187            9th
# 7            8   52   Self-emp-not-inc        209642        HS-grad
# 8            9   31            Private         45781        Masters
# 9           10   42            Private        159449      Bachelors
# 10          11   37            Private        280464   Some-college
# 11          12   30          State-gov        141297      Bachelors
# 12          13   23            Private        122272      Bachelors
# ...

# %%
#Imputacion por la mediana usando scikit-learn si la variable es cuantitativa y por la moda si la variable es  cualitativa 
import numpy as np
from sklearn.preprocessing import Imputer
from sklearn.base import TransformerMixin

class DataFrameImputer(TransformerMixin):

    def fit(self, X, y=None):

        self.fill = pd.Series([X[c].value_counts().index[0]
            if X[c].dtype == np.dtype('O') else X[c].median() for c in X],
            index=X.columns)

        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)
X=x
xt = DataFrameImputer().fit_transform(X)

# %%
xt.head(20)
# Out:
#     Unnamed: 0  age         employment  final-weight      education  \
# 0            1   39          State-gov         77516      Bachelors
# 1            2   50   Self-emp-not-inc         83311      Bachelors
# 2            3   38            Private        215646        HS-grad
# 3            4   53            Private        234721           11th
# 4            5   28            Private        338409      Bachelors
# 5            6   37            Private        284582        Masters
# 6            7   49            Private        160187            9th
# 7            8   52   Self-emp-not-inc        209642        HS-grad
# 8            9   31            Private         45781        Masters
# 9           10   42            Private        159449      Bachelors
# 10          11   37            Private        280464   Some-college
# 11          12   30          State-gov        141297      Bachelors
# 12          13   23            Private        122272      Bachelors
# ...
